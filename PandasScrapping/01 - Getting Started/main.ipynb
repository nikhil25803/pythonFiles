# %%
import pandas as pd

# scrapper1 = pd.read_html(
#     'https://www.nirfindia.org/2022/EngineeringRankingALL.html')


# scrapper1

# %%
scrapper2 = pd.read_html(
    'https://www.nirfindia.org/2022/EngineeringRanking.html')
scrapper2
# Out:
# [     Institute ID                                               Name  \
#  0     IR-E-U-0456  Indian Institute of Technology MadrasMore Deta...
#  1     IR-E-I-1074  Indian Institute of Technology, DelhiMore Deta...
#  2     IR-E-U-0306  Indian Institute of Technology, BombayMore Det...
#  3     IR-E-I-1075  Indian Institute of Technology KanpurMore Deta...
#  4     IR-E-U-0573  Indian Institute of Technology, KharagpurMore ...
#  ..            ...                                                ...
#  195   IR-E-U-0854         KLE Technological UniversityMore Details |
#  196  IR-E-C-33777  Shri Vile Parle Kelavani Mandal`s Dwarkadas J....
#  197  IR-E-C-16504  Sri Venkateswara College of Engineering and Te...
#  198   IR-E-C-1336  BMS Institute of Technology & ManagementMore D...
#  199  IR-E-C-19582  Vidya Jyothi Institute of TechnologyMore Detai...
#
#                  City           State  Score  Rank
#  0            Chennai      Tamil Nadu  90.04     1
# ...

# %%
dataFrame = scrapper2[0]

# %%
dataFrame
# Out:
#      Institute ID                                               Name  \
# 0     IR-E-U-0456  Indian Institute of Technology MadrasMore Deta...
# 1     IR-E-I-1074  Indian Institute of Technology, DelhiMore Deta...
# 2     IR-E-U-0306  Indian Institute of Technology, BombayMore Det...
# 3     IR-E-I-1075  Indian Institute of Technology KanpurMore Deta...
# 4     IR-E-U-0573  Indian Institute of Technology, KharagpurMore ...
# ..            ...                                                ...
# 195   IR-E-U-0854         KLE Technological UniversityMore Details |
# 196  IR-E-C-33777  Shri Vile Parle Kelavani Mandal`s Dwarkadas J....
# 197  IR-E-C-16504  Sri Venkateswara College of Engineering and Te...
# 198   IR-E-C-1336  BMS Institute of Technology & ManagementMore D...
# 199  IR-E-C-19582  Vidya Jyothi Institute of TechnologyMore Detai...
#
#                 City           State  Score  Rank
# 0            Chennai      Tamil Nadu  90.04     1
# ...

# %%
dataFrame.groupby('State').apply(lambda s: s == 'Bihar')
# Out:
#      Institute ID   Name   City  State  Score   Rank
# 0           False  False  False  False  False  False
# 1           False  False  False  False  False  False
# 2           False  False  False  False  False  False
# 3           False  False  False  False  False  False
# 4           False  False  False  False  False  False
# ..            ...    ...    ...    ...    ...    ...
# 195         False  False  False  False  False  False
# 196         False  False  False  False  False  False
# 197         False  False  False  False  False  False
# 198         False  False  False  False  False  False
# 199         False  False  False  False  False  False
#
# [200 rows x 6 columns]

# %%
dataFrame.sort_values(by='State')
# Out:
#      Institute ID                                               Name  \
# 164  IR-E-C-26929  Sree Vidyanikethan Engineering CollegeMore Det...
# 140  IR-E-C-18010  Velagapudi Ramakrishna Siddhartha Engineering ...
# 101   IR-E-U-0011  Gandhi Institute of Technology and Management ...
# 43    IR-E-U-0020  Koneru Lakshmaiah Education Foundation Univers...
# 98    IR-E-U-0043  Vignan's Foundation for Science, Technology an...
# ..            ...                                                ...
# 60    IR-E-U-0564  University of Petroleum and Energy StudiesMore...
# 33    IR-E-U-0577  National Institute of Technology DurgapurMore ...
# 39    IR-E-U-0584  Indian Institute of Engineering Science and Te...
# 4     IR-E-U-0573  Indian Institute of Technology, KharagpurMore ...
# 10    IR-E-U-0575                  Jadavpur UniversityMore Details |
#
#               City           State  Score  Rank
# 164       Tirupati  Andhra Pradesh  36.08   165
# ...

# %%
dataFrame.sort_values(by='State').apply(lambda name: name=='Bihar')
# Out:
#      Institute ID   Name   City  State  Score   Rank
# 164         False  False  False  False  False  False
# 140         False  False  False  False  False  False
# 101         False  False  False  False  False  False
# 43          False  False  False  False  False  False
# 98          False  False  False  False  False  False
# ..            ...    ...    ...    ...    ...    ...
# 60          False  False  False  False  False  False
# 33          False  False  False  False  False  False
# 39          False  False  False  False  False  False
# 4           False  False  False  False  False  False
# 10          False  False  False  False  False  False
#
# [200 rows x 6 columns]
